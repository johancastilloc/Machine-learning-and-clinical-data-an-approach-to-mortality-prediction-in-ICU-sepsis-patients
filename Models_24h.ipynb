# %% [markdown]
# ## Libraries

# %%
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.neural_network import MLPClassifier
from xgboost.sklearn import XGBClassifier
from lightgbm.sklearn import LGBMClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import StratifiedKFold
from confidenceinterval.ModelEvaluationUtils import (
    train_and_evaluate_sofa,
    z_score,
    plot_roc_auc,
    train_and_evaluate_models, 
    calculate_ci_models, 
    plot_roc_auc_models,
    select_data
)
from confidenceinterval.goldstandard import (
    evaluation_metrics,
    max_th_f1
)

# %% [markdown]
# ## Load the data, All variables

# %%
x_train, x_test, y_train, y_test = select_data('johan_variables', 68, 'ya_imputados/mimic2448f_complete.csv', 'ya_imputados/eicu2448f_complete.csv') 
x_train.shape, x_test.shape, y_train.shape, y_test.shape # Print the shapes of the training and testing data and labels
# Out:
# ((7511, 68), (3786, 68), (7511,), (3786,))

# %% [markdown]
# ## Models

# %%
models = [LogisticRegression(solver= "sag"), #Stochastic Average Gradient (SAG) is efficient for large datasets by updating model parameters with small random batches, reducing computation time.
          SVC(probability=True), #probability=True enables probability estimates using 5-fold cross-validation.
          DecisionTreeClassifier(),
          RandomForestClassifier(),
          GradientBoostingClassifier(),
          MLPClassifier(),
          XGBClassifier(),
          LGBMClassifier()]

# %% [markdown]
# ## Training and Testing the model

# %%
# z-score the data
x_train_z, x_test_z = z_score(x_train, x_test)
# stratified k-fold cross-validation
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=1)

# train and evaluate the model
results = train_and_evaluate_models(x_train_z, y_train, x_test_z, y_test, skf, models)
# Out:
# Training and evaluating model: LogisticRegression
# c:\Users\JOHAN\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# Fold 1: Train AUC: 0.9445
#  Validation AUC: 0.9391
#  Test AUC: 0.8784
# c:\Users\JOHAN\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# Fold 2: Train AUC: 0.9449
#  Validation AUC: 0.9424
#  Test AUC: 0.8759
# c:\Users\JOHAN\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# Fold 3: Train AUC: 0.9476
#  Validation AUC: 0.9275
#  Test AUC: 0.8763
# c:\Users\JOHAN\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# Fold 4: Train AUC: 0.9446
#  Validation AUC: 0.9446
#  Test AUC: 0.8803
# c:\Users\JOHAN\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# Fold 5: Train AUC: 0.9460
#  Validation AUC: 0.9389
#  Test AUC: 0.8771
# Training and evaluating model: SVC
# Fold 1: Train AUC: 0.9765
#  Validation AUC: 0.9315
#  Test AUC: 0.8466
# Fold 2: Train AUC: 0.9762
#  Validation AUC: 0.9437
#  Test AUC: 0.8346
# Fold 3: Train AUC: 0.9782
#  Validation AUC: 0.9264
#  Test AUC: 0.8439
# Fold 4: Train AUC: 0.9768
#  Validation AUC: 0.9400
#  Test AUC: 0.8359
# Fold 5: Train AUC: 0.9759
#  Validation AUC: 0.9425
#  Test AUC: 0.8331
# Training and evaluating model: DecisionTreeClassifier
# Fold 1: Train AUC: 1.0000
#  Validation AUC: 0.7597
#  Test AUC: 0.6602
# Fold 2: Train AUC: 1.0000
#  Validation AUC: 0.7454
#  Test AUC: 0.6552
# Fold 3: Train AUC: 1.0000
#  Validation AUC: 0.7507
#  Test AUC: 0.6618
# Fold 4: Train AUC: 1.0000
#  Validation AUC: 0.7575
#  Test AUC: 0.6577
# Fold 5: Train AUC: 1.0000
#  Validation AUC: 0.7563
#  Test AUC: 0.6405
# Training and evaluating model: RandomForestClassifier
# Fold 1: Train AUC: 1.0000
#  Validation AUC: 0.9336
#  Test AUC: 0.8646
# Fold 2: Train AUC: 1.0000
#  Validation AUC: 0.9453
#  Test AUC: 0.8585
# Fold 3: Train AUC: 1.0000
#  Validation AUC: 0.9225
#  Test AUC: 0.8638
# Fold 4: Train AUC: 1.0000
#  Validation AUC: 0.9284
#  Test AUC: 0.8612
# Fold 5: Train AUC: 1.0000
#  Validation AUC: 0.9348
#  Test AUC: 0.8578
# Training and evaluating model: GradientBoostingClassifier
# Fold 1: Train AUC: 0.9772
#  Validation AUC: 0.9451
#  Test AUC: 0.8715
# Fold 2: Train AUC: 0.9795
#  Validation AUC: 0.9461
#  Test AUC: 0.8562
# Fold 3: Train AUC: 0.9809
#  Validation AUC: 0.9241
#  Test AUC: 0.8653
# Fold 4: Train AUC: 0.9774
#  Validation AUC: 0.9448
#  Test AUC: 0.8743
# Fold 5: Train AUC: 0.9796
#  Validation AUC: 0.9434
#  Test AUC: 0.8677
# Training and evaluating model: MLPClassifier
# c:\Users\JOHAN\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 1: Train AUC: 1.0000
#  Validation AUC: 0.8954
#  Test AUC: 0.8131
# c:\Users\JOHAN\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 2: Train AUC: 1.0000
#  Validation AUC: 0.9039
#  Test AUC: 0.8135
# c:\Users\JOHAN\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 3: Train AUC: 1.0000
#  Validation AUC: 0.9125
#  Test AUC: 0.8334
# c:\Users\JOHAN\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 4: Train AUC: 1.0000
#  Validation AUC: 0.9198
#  Test AUC: 0.8268
# c:\Users\JOHAN\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 5: Train AUC: 1.0000
#  Validation AUC: 0.9159
#  Test AUC: 0.8251
# Training and evaluating model: XGBClassifier
# Fold 1: Train AUC: 1.0000
#  Validation AUC: 0.9457
#  Test AUC: 0.8754
# Fold 2: Train AUC: 1.0000
#  Validation AUC: 0.9458
#  Test AUC: 0.8742
# Fold 3: Train AUC: 1.0000
#  Validation AUC: 0.9232
#  Test AUC: 0.8713
# Fold 4: Train AUC: 1.0000
#  Validation AUC: 0.9454
#  Test AUC: 0.8728
# Fold 5: Train AUC: 1.0000
#  Validation AUC: 0.9451
#  Test AUC: 0.8750
# Training and evaluating model: LGBMClassifier
# [LightGBM] [Info] Number of positive: 932, number of negative: 5076
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001020 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 7060
# [LightGBM] [Info] Number of data points in the train set: 6008, number of used features: 68
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.155126 -> initscore=-1.694946
# [LightGBM] [Info] Start training from score -1.694946
# Fold 1: Train AUC: 1.0000
#  Validation AUC: 0.9441
#  Test AUC: 0.8744
# [LightGBM] [Info] Number of positive: 932, number of negative: 5077
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004708 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7052
# [LightGBM] [Info] Number of data points in the train set: 6009, number of used features: 68
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.155101 -> initscore=-1.695143
# [LightGBM] [Info] Start training from score -1.695143
# Fold 2: Train AUC: 1.0000
#  Validation AUC: 0.9431
#  Test AUC: 0.8783
# [LightGBM] [Info] Number of positive: 932, number of negative: 5077
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.013258 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 7056
# [LightGBM] [Info] Number of data points in the train set: 6009, number of used features: 68
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.155101 -> initscore=-1.695143
# [LightGBM] [Info] Start training from score -1.695143
# Fold 3: Train AUC: 1.0000
#  Validation AUC: 0.9273
#  Test AUC: 0.8776
# [LightGBM] [Info] Number of positive: 932, number of negative: 5077
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.010152 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 7072
# [LightGBM] [Info] Number of data points in the train set: 6009, number of used features: 68
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.155101 -> initscore=-1.695143
# [LightGBM] [Info] Start training from score -1.695143
# Fold 4: Train AUC: 1.0000
#  Validation AUC: 0.9455
#  Test AUC: 0.8733
# [LightGBM] [Info] Number of positive: 932, number of negative: 5077
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004018 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 7052
# [LightGBM] [Info] Number of data points in the train set: 6009, number of used features: 68
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.155101 -> initscore=-1.695143
# [LightGBM] [Info] Start training from score -1.695143
# Fold 5: Train AUC: 1.0000
#  Validation AUC: 0.9486
#  Test AUC: 0.8760

# %% [markdown]
# ### Validation data result

# %%
# Calculate AUC and confidence intervals for validation data
auc_results_val= calculate_ci_models(results, truth_key='val_truths', preds_key='val_preds', alpha=0.95)

for model_name, auc, (ci_lower, ci_upper) in auc_results_val:
    print(f"AUC on validation data for {model_name}: {auc:.4g} 95% CI ({ci_lower:.4g} - {ci_upper:.4g})")
# Out:
# AUC on validation data for LogisticRegression: 0.9385 95% CI (0.9331 - 0.9439)
# AUC on validation data for SVC: 0.9365 95% CI (0.931 - 0.942)
# AUC on validation data for DecisionTreeClassifier: 0.7539 95% CI (0.7442 - 0.7637)
# AUC on validation data for RandomForestClassifier: 0.9326 95% CI (0.927 - 0.9383)
# AUC on validation data for GradientBoostingClassifier: 0.9407 95% CI (0.9353 - 0.946)
# AUC on validation data for MLPClassifier: 0.9088 95% CI (0.9023 - 0.9153)
# AUC on validation data for XGBClassifier: 0.9406 95% CI (0.9353 - 0.946)
# AUC on validation data for LGBMClassifier: 0.9415 95% CI (0.9362 - 0.9468)

# %% [markdown]
# ### Test data result

# %%
# Calculate AUC and confidence intervals for validation data
auc_results_test = calculate_ci_models(results, truth_key='test_truths', preds_key='test_preds', alpha=0.95)

for model_name, auc, (ci_lower, ci_upper) in auc_results_test:
    print(f"AUC on test data for {model_name}: {auc:.4g} 95% CI ({ci_lower:.4g} - {ci_upper:.4g})")
# Out:
# AUC on test data for LogisticRegression: 0.8775 95% CI (0.8728 - 0.8821)
# AUC on test data for SVC: 0.8388 95% CI (0.8336 - 0.8441)
# AUC on test data for DecisionTreeClassifier: 0.6551 95% CI (0.6483 - 0.6619)
# AUC on test data for RandomForestClassifier: 0.8611 95% CI (0.8562 - 0.8661)
# AUC on test data for GradientBoostingClassifier: 0.8668 95% CI (0.862 - 0.8716)
# AUC on test data for MLPClassifier: 0.8214 95% CI (0.816 - 0.8269)
# AUC on test data for XGBClassifier: 0.8736 95% CI (0.8688 - 0.8783)
# AUC on test data for LGBMClassifier: 0.8758 95% CI (0.8711 - 0.8805)

# %% [markdown]
# ## ROC curve - Train

# %%
plot_roc_auc_models(results, 'val_truths', 'val_preds', auc_results_val, 'MIMIC IV v3.0 24h ROC AUCs across 8 models')

# %% [markdown]
# ## ROC curve - Test

# %%
plot_roc_auc_models(results, 'test_truths', 'test_preds', auc_results_test,'eICU v2.0 24h ROC AUCs across 8 models')

# %% [markdown]
# ## ROC curve - SOFA

# %%
x_train_sofa, x_test_sofa, y_train_sofa, y_test_sofa = select_data('SOFA', 1, 'ya_imputados/mimic2448f_complete.csv', 'ya_imputados/eicu2448f_complete.csv') 
results_sofa = train_and_evaluate_sofa(x_train_sofa, y_train_sofa, x_test_sofa, y_test_sofa)
auc_results_val_sofa= calculate_ci_models(results_sofa, truth_key='val_truths', preds_key='val_preds', alpha=0.95)
auc_results_test_sofa = calculate_ci_models(results_sofa, truth_key='test_truths', preds_key='test_preds', alpha=0.95)
for model_name, auc, (ci_lower, ci_upper) in auc_results_val_sofa:
    print(f"AUC on validation data for {model_name}: {auc:.4g} 95% CI ({ci_lower:.4g} - {ci_upper:.4g})")
for model_name, auc, (ci_lower, ci_upper) in auc_results_test_sofa:
    print(f"AUC on test data for {model_name}: {auc:.4g} 95% CI ({ci_lower:.4g} - {ci_upper:.4g})")
_=plot_roc_auc(results_sofa['SOFA']['val_truths'], results_sofa['SOFA']['val_preds'], results_sofa['SOFA']['test_truths'], results_sofa['SOFA']['test_preds'], auc_results_val_sofa[0][2][0], auc_results_val_sofa[0][2][1], auc_results_test_sofa[0][2][0], auc_results_test_sofa[0][2][1],'24h ROC AUC for SOFA')
# Out:
# AUC on validation data for SOFA: 0.7121 95% CI (0.7019 - 0.7224)
# AUC on test data for SOFA: 0.7973 95% CI (0.7845 - 0.8101)

# %% [markdown]
# ## Evaluation Metrics

# %% [markdown]
# ### With Fine Tuning - Optuna

# %%
modelsft = [LGBMClassifier(objective='binary',
                               boosting_type='gbdt',
                               metric='auc',
                               device_type='gpu',
                               importance_type='gain',
                               verbosity=2,
                               feature_pre_filter=False,  
                               lambda_l1= 0.0002203416148787027,
                               lambda_l2= 0.001405449935872556,
                               num_leaves=3,
                               max_depth= 10,
                               learning_rate= 0.1,
                               feature_fraction=0.5,
                               bagging_fraction= 0.8282909106983775,
                               bagging_freq=3,
                               min_child_samples= 25)]

# %%
# z-score the data
x_train_ft, x_test_ft = z_score(x_train, x_test)
# stratified k-fold cross-validation
skfft = StratifiedKFold(n_splits=5, shuffle=True, random_state=1)

# train and evaluate the model
resultsft = train_and_evaluate_models(x_train_ft, y_train, x_test_ft, y_test, skfft, modelsft)
# Calculate AUC and confidence intervals for validation data
auc_results_valft= calculate_ci_models(resultsft, truth_key='val_truths', preds_key='val_preds', alpha=0.95)
for model_name, auc, (ci_lower, ci_upper) in auc_results_valft:
    print(f"AUC on validation data for {model_name}: {auc:.4g} 95% CI ({ci_lower:.4g} - {ci_upper:.4g})")
# Calculate AUC and confidence intervals for test data
auc_results_testft = calculate_ci_models(resultsft, truth_key='test_truths', preds_key='test_preds', alpha=0.95)
for model_name, auc, (ci_lower, ci_upper) in auc_results_testft:
    print(f"AUC on test data for {model_name}: {auc:.4g} 95% CI ({ci_lower:.4g} - {ci_upper:.4g})")
fpr_valft, tpr_valft, th_valft, fpr_testft, tpr_testft, th_testft = plot_roc_auc(resultsft['LGBMClassifier']['val_truths'], resultsft['LGBMClassifier']['val_preds'], resultsft['LGBMClassifier']['test_truths'], resultsft['LGBMClassifier']['test_preds'], auc_results_valft[0][2][0], auc_results_valft[0][2][1], auc_results_testft[0][2][0], auc_results_testft[0][2][1],'24h ROC AUC for LGBM')
# Out:
# Training and evaluating model: LGBMClassifier
# [LightGBM] [Warning] feature_fraction is set=0.5, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5
# [LightGBM] [Warning] lambda_l1 is set=0.0002203416148787027, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.0002203416148787027
# [LightGBM] [Warning] lambda_l2 is set=0.001405449935872556, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.001405449935872556
# [LightGBM] [Warning] bagging_fraction is set=0.8282909106983775, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8282909106983775
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# [LightGBM] [Warning] feature_fraction is set=0.5, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5
# [LightGBM] [Warning] lambda_l1 is set=0.0002203416148787027, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.0002203416148787027
# [LightGBM] [Warning] lambda_l2 is set=0.001405449935872556, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.001405449935872556
# [LightGBM] [Warning] bagging_fraction is set=0.8282909106983775, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8282909106983775
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# [LightGBM] [Info] Number of positive: 932, number of negative: 5076
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Debug] Dataset::GetMultiBinFromSparseFeatures: sparse rate 0.905085
# [LightGBM] [Info] Total Bins 7060
# [LightGBM] [Info] Number of data points in the train set: 6008, number of used features: 68
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce GTX 1650, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.32 MB) transferred to GPU in 0.001893 secs. 1 sparse feature groups
# [LightGBM] [Debug] Use subset for bagging
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.155126 -> initscore=-1.694946
# [LightGBM] [Info] Start training from score -1.694946
# [LightGBM] [Debug] Re-bagging, using 4966 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.27 MB) transferred to GPU in 0.001662 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 4981 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.27 MB) transferred to GPU in 0.001623 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 4989 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.27 MB) transferred to GPU in 0.001747 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 4953 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.26 MB) transferred to GPU in 0.001824 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 4937 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.26 MB) transferred to GPU in 0.001607 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 4988 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.27 MB) transferred to GPU in 0.001965 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 4994 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.27 MB) transferred to GPU in 0.002058 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 5012 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.27 MB) transferred to GPU in 0.002135 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 5003 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.27 MB) transferred to GPU in 0.001595 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 4951 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.26 MB) transferred to GPU in 0.001983 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 4958 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.26 MB) transferred to GPU in 0.001526 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 4947 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.26 MB) transferred to GPU in 0.002074 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 4959 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.26 MB) transferred to GPU in 0.001661 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 5038 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.27 MB) transferred to GPU in 0.001813 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 5013 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.27 MB) transferred to GPU in 0.001600 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 4970 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.27 MB) transferred to GPU in 0.001544 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 4994 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.27 MB) transferred to GPU in 0.001456 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 5015 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.27 MB) transferred to GPU in 0.001661 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 5013 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.27 MB) transferred to GPU in 0.001396 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 4994 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.27 MB) transferred to GPU in 0.001710 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 4929 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.26 MB) transferred to GPU in 0.001596 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 4941 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.26 MB) transferred to GPU in 0.001757 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 5027 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.27 MB) transferred to GPU in 0.001506 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 4919 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.26 MB) transferred to GPU in 0.001604 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 4967 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.27 MB) transferred to GPU in 0.001584 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 4983 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.27 MB) transferred to GPU in 0.001675 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 4988 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.27 MB) transferred to GPU in 0.001602 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 4965 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.27 MB) transferred to GPU in 0.001370 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 4981 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.27 MB) transferred to GPU in 0.001514 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 4946 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.26 MB) transferred to GPU in 0.001530 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 4966 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.27 MB) transferred to GPU in 0.001542 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 4981 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.27 MB) transferred to GPU in 0.001725 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 4952 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.26 MB) transferred to GPU in 0.001517 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 5005 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.27 MB) transferred to GPU in 0.001434 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Warning] feature_fraction is set=0.5, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5
# [LightGBM] [Warning] lambda_l1 is set=0.0002203416148787027, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.0002203416148787027
# [LightGBM] [Warning] lambda_l2 is set=0.001405449935872556, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.001405449935872556
# [LightGBM] [Warning] bagging_fraction is set=0.8282909106983775, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8282909106983775
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# [LightGBM] [Warning] feature_fraction is set=0.5, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5
# [LightGBM] [Warning] lambda_l1 is set=0.0002203416148787027, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.0002203416148787027
# [LightGBM] [Warning] lambda_l2 is set=0.001405449935872556, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.001405449935872556
# [LightGBM] [Warning] bagging_fraction is set=0.8282909106983775, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8282909106983775
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# [LightGBM] [Warning] feature_fraction is set=0.5, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5
# [LightGBM] [Warning] lambda_l1 is set=0.0002203416148787027, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.0002203416148787027
# [LightGBM] [Warning] lambda_l2 is set=0.001405449935872556, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.001405449935872556
# [LightGBM] [Warning] bagging_fraction is set=0.8282909106983775, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8282909106983775
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# Fold 1: Train AUC: 0.9535
#  Validation AUC: 0.9393
#  Test AUC: 0.8766
# [LightGBM] [Warning] feature_fraction is set=0.5, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5
# [LightGBM] [Warning] lambda_l1 is set=0.0002203416148787027, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.0002203416148787027
# [LightGBM] [Warning] lambda_l2 is set=0.001405449935872556, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.001405449935872556
# [LightGBM] [Warning] bagging_fraction is set=0.8282909106983775, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8282909106983775
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# [LightGBM] [Warning] feature_fraction is set=0.5, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5
# [LightGBM] [Warning] lambda_l1 is set=0.0002203416148787027, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.0002203416148787027
# [LightGBM] [Warning] lambda_l2 is set=0.001405449935872556, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.001405449935872556
# [LightGBM] [Warning] bagging_fraction is set=0.8282909106983775, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8282909106983775
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# [LightGBM] [Info] Number of positive: 932, number of negative: 5077
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Debug] Dataset::GetMultiBinFromSparseFeatures: sparse rate 0.905198
# [LightGBM] [Info] Total Bins 7052
# [LightGBM] [Info] Number of data points in the train set: 6009, number of used features: 68
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce GTX 1650, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.32 MB) transferred to GPU in 0.001893 secs. 1 sparse feature groups
# [LightGBM] [Debug] Use subset for bagging
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.155101 -> initscore=-1.695143
# [LightGBM] [Info] Start training from score -1.695143
# [LightGBM] [Debug] Re-bagging, using 4967 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.27 MB) transferred to GPU in 0.001572 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 4982 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.27 MB) transferred to GPU in 0.001570 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 4988 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.27 MB) transferred to GPU in 0.001669 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 4955 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.26 MB) transferred to GPU in 0.001566 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 4939 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.26 MB) transferred to GPU in 0.001605 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 4988 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.27 MB) transferred to GPU in 0.001729 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 4995 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.27 MB) transferred to GPU in 0.001554 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 5011 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.27 MB) transferred to GPU in 0.001446 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 5005 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.27 MB) transferred to GPU in 0.001412 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 4953 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.26 MB) transferred to GPU in 0.001649 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 4959 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.26 MB) transferred to GPU in 0.001503 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 4949 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.26 MB) transferred to GPU in 0.001675 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 4956 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.26 MB) transferred to GPU in 0.001487 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 5042 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.27 MB) transferred to GPU in 0.001418 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 5011 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.27 MB) transferred to GPU in 0.001900 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 4973 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.27 MB) transferred to GPU in 0.001575 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 4993 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.27 MB) transferred to GPU in 0.001537 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 5017 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.27 MB) transferred to GPU in 0.001521 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 5014 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.27 MB) transferred to GPU in 0.001433 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 4998 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.27 MB) transferred to GPU in 0.001573 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 4925 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.26 MB) transferred to GPU in 0.001653 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 4944 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.26 MB) transferred to GPU in 0.001463 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 5027 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.27 MB) transferred to GPU in 0.001520 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 4919 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.26 MB) transferred to GPU in 0.001677 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 4969 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.27 MB) transferred to GPU in 0.001577 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 4983 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.27 MB) transferred to GPU in 0.001461 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 4988 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.27 MB) transferred to GPU in 0.001569 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 4969 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.27 MB) transferred to GPU in 0.001528 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 4980 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.27 MB) transferred to GPU in 0.001420 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 4950 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.26 MB) transferred to GPU in 0.001612 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 4962 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.26 MB) transferred to GPU in 0.001614 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 4983 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.27 MB) transferred to GPU in 0.001438 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 4953 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.26 MB) transferred to GPU in 0.001475 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 5008 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.27 MB) transferred to GPU in 0.001574 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Warning] feature_fraction is set=0.5, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5
# [LightGBM] [Warning] lambda_l1 is set=0.0002203416148787027, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.0002203416148787027
# [LightGBM] [Warning] lambda_l2 is set=0.001405449935872556, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.001405449935872556
# [LightGBM] [Warning] bagging_fraction is set=0.8282909106983775, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8282909106983775
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# [LightGBM] [Warning] feature_fraction is set=0.5, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5
# [LightGBM] [Warning] lambda_l1 is set=0.0002203416148787027, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.0002203416148787027
# [LightGBM] [Warning] lambda_l2 is set=0.001405449935872556, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.001405449935872556
# [LightGBM] [Warning] bagging_fraction is set=0.8282909106983775, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8282909106983775
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# [LightGBM] [Warning] feature_fraction is set=0.5, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5
# [LightGBM] [Warning] lambda_l1 is set=0.0002203416148787027, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.0002203416148787027
# [LightGBM] [Warning] lambda_l2 is set=0.001405449935872556, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.001405449935872556
# [LightGBM] [Warning] bagging_fraction is set=0.8282909106983775, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8282909106983775
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# Fold 2: Train AUC: 0.9531
#  Validation AUC: 0.9477
#  Test AUC: 0.8737
# [LightGBM] [Warning] feature_fraction is set=0.5, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5
# [LightGBM] [Warning] lambda_l1 is set=0.0002203416148787027, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.0002203416148787027
# [LightGBM] [Warning] lambda_l2 is set=0.001405449935872556, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.001405449935872556
# [LightGBM] [Warning] bagging_fraction is set=0.8282909106983775, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8282909106983775
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# [LightGBM] [Warning] feature_fraction is set=0.5, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5
# [LightGBM] [Warning] lambda_l1 is set=0.0002203416148787027, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.0002203416148787027
# [LightGBM] [Warning] lambda_l2 is set=0.001405449935872556, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.001405449935872556
# [LightGBM] [Warning] bagging_fraction is set=0.8282909106983775, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8282909106983775
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# [LightGBM] [Info] Number of positive: 932, number of negative: 5077
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Debug] Dataset::GetMultiBinFromSparseFeatures: sparse rate 0.905863
# [LightGBM] [Info] Total Bins 7056
# [LightGBM] [Info] Number of data points in the train set: 6009, number of used features: 68
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce GTX 1650, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.32 MB) transferred to GPU in 0.001778 secs. 1 sparse feature groups
# [LightGBM] [Debug] Use subset for bagging
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.155101 -> initscore=-1.695143
# [LightGBM] [Info] Start training from score -1.695143
# [LightGBM] [Debug] Re-bagging, using 4967 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.27 MB) transferred to GPU in 0.001558 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 4982 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.27 MB) transferred to GPU in 0.001690 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 4988 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.27 MB) transferred to GPU in 0.001524 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 4955 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.26 MB) transferred to GPU in 0.001556 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 4939 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.26 MB) transferred to GPU in 0.001392 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 4988 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.27 MB) transferred to GPU in 0.001458 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 4995 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.27 MB) transferred to GPU in 0.001676 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 5011 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.27 MB) transferred to GPU in 0.001510 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 5005 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.27 MB) transferred to GPU in 0.001454 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 4953 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.26 MB) transferred to GPU in 0.001688 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 4959 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.26 MB) transferred to GPU in 0.001521 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 4949 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.26 MB) transferred to GPU in 0.001601 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 4956 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.26 MB) transferred to GPU in 0.001507 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 5042 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.27 MB) transferred to GPU in 0.001757 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 5011 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.27 MB) transferred to GPU in 0.001384 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 4973 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.27 MB) transferred to GPU in 0.001496 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 4993 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.27 MB) transferred to GPU in 0.001488 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 5017 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.27 MB) transferred to GPU in 0.001469 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 5014 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.27 MB) transferred to GPU in 0.001622 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 4998 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.27 MB) transferred to GPU in 0.001362 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 4925 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.26 MB) transferred to GPU in 0.001427 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 4944 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.26 MB) transferred to GPU in 0.001371 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 5027 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.27 MB) transferred to GPU in 0.001476 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 4919 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.26 MB) transferred to GPU in 0.001441 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# ...
# [LightGBM] [Debug] Re-bagging, using 4967 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.27 MB) transferred to GPU in 0.001692 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 4982 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.27 MB) transferred to GPU in 0.001545 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 4988 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.27 MB) transferred to GPU in 0.001723 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 4955 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.26 MB) transferred to GPU in 0.001618 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 4939 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.26 MB) transferred to GPU in 0.001937 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 4988 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.27 MB) transferred to GPU in 0.001577 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 4995 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.27 MB) transferred to GPU in 0.001899 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 5011 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.27 MB) transferred to GPU in 0.001680 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 5005 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.27 MB) transferred to GPU in 0.001379 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 4953 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.26 MB) transferred to GPU in 0.001496 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 4959 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.26 MB) transferred to GPU in 0.001315 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 4949 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.26 MB) transferred to GPU in 0.001321 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 4956 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.26 MB) transferred to GPU in 0.001411 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 5042 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.27 MB) transferred to GPU in 0.001613 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 5011 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.27 MB) transferred to GPU in 0.001826 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 4973 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.27 MB) transferred to GPU in 0.001395 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 4993 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.27 MB) transferred to GPU in 0.001388 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 5017 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.27 MB) transferred to GPU in 0.001370 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 5014 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.27 MB) transferred to GPU in 0.001368 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 4998 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.27 MB) transferred to GPU in 0.001376 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 4925 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.26 MB) transferred to GPU in 0.001402 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 4944 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.26 MB) transferred to GPU in 0.001406 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 5027 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.27 MB) transferred to GPU in 0.001580 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 4919 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.26 MB) transferred to GPU in 0.001599 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 4969 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.27 MB) transferred to GPU in 0.001408 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 4983 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.27 MB) transferred to GPU in 0.001361 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 4988 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.27 MB) transferred to GPU in 0.001405 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 4969 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.27 MB) transferred to GPU in 0.001557 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 4980 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.27 MB) transferred to GPU in 0.001371 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 4950 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.26 MB) transferred to GPU in 0.001382 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 4962 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.26 MB) transferred to GPU in 0.001460 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 4983 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.27 MB) transferred to GPU in 0.001895 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 4953 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.26 MB) transferred to GPU in 0.001419 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 5008 data to train
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 56 dense feature groups (0.27 MB) transferred to GPU in 0.001566 secs. 1 sparse feature groups
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Warning] feature_fraction is set=0.5, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5
# [LightGBM] [Warning] lambda_l1 is set=0.0002203416148787027, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.0002203416148787027
# [LightGBM] [Warning] lambda_l2 is set=0.001405449935872556, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.001405449935872556
# [LightGBM] [Warning] bagging_fraction is set=0.8282909106983775, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8282909106983775
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# [LightGBM] [Warning] feature_fraction is set=0.5, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5
# [LightGBM] [Warning] lambda_l1 is set=0.0002203416148787027, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.0002203416148787027
# [LightGBM] [Warning] lambda_l2 is set=0.001405449935872556, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.001405449935872556
# [LightGBM] [Warning] bagging_fraction is set=0.8282909106983775, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8282909106983775
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# [LightGBM] [Warning] feature_fraction is set=0.5, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5
# [LightGBM] [Warning] lambda_l1 is set=0.0002203416148787027, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.0002203416148787027
# [LightGBM] [Warning] lambda_l2 is set=0.001405449935872556, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.001405449935872556
# [LightGBM] [Warning] bagging_fraction is set=0.8282909106983775, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8282909106983775
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# Fold 5: Train AUC: 0.9545
#  Validation AUC: 0.9406
#  Test AUC: 0.8708
# AUC on validation data for LGBMClassifier: 0.9391 95% CI (0.9337 - 0.9445)
# AUC on test data for LGBMClassifier: 0.8731 95% CI (0.8684 - 0.8778)

# %% [markdown]
# ## Max F1 - validation

# %%
max_th_f1(th_valft,resultsft['LGBMClassifier']['val_truths'],resultsft['LGBMClassifier']['val_preds'],  resultsft['LGBMClassifier']['test_truths'],resultsft['LGBMClassifier']['test_preds'],'Confusion matrix for MIMIC IV v3.0 24h with maximum F1 score','Confusion matrix for eICU v2.0 24h with maximum F1 score','MIMIC IV v3.0 24h F1 score vs Threshold')
# Out:
# Optimal Threshold for Maximum F1 Score: 0.3381
# Maximum F1 Score: 0.7386
# Validation results:
# Threshold: 0.3381
# Precision: 0.7790
# Recall: 0.7021
# F1 Score: 0.7386
# Test results:
# With the validation threshold: 0.3381
# Precision: 0.6612
# Recall: 0.4849
# F1 Score: 0.5595
