# %% [markdown]
# ## Libraries

# %%
import pandas as pd
import numpy as np
import os
# change the working directory to the parent directory
current_dir = os.path.abspath(os.getcwd())

parent_dir = os.path.abspath(os.path.join(current_dir, '..'))
os.chdir(parent_dir)

# %% [markdown]
# ## Load data and flag

# %%
df1 = pd.read_csv('datapre/eicu/conflag_eICU_24_48.csv')
df2 = pd.read_csv('datapre/mimic/conflag_mimic_24_48.csv')
df3 = pd.read_csv('datapre/eicu/conflag_eICU_12_36.csv')
df4 = pd.read_csv('datapre/mimic/conflag_mimic_12_36.csv')
df5 = pd.read_csv('datapre/eicu/conflag_eICU_48_72.csv')
df6 = pd.read_csv('datapre/mimic/conflag_mimic_48_72.csv')
df7 = pd.read_csv('ya_imputados/sinflag/eicu1236_complete.csv')
df8 = pd.read_csv('ya_imputados/sinflag/eicu2448_complete.csv')
df9 = pd.read_csv('ya_imputados/eicu4872_complete.csv')
df10 = pd.read_csv('ya_imputados/sinflag/mimic1236_complete.csv')
df11 = pd.read_csv('ya_imputados/sinflag/mimic2448_complete.csv')
df12 = pd.read_csv('ya_imputados/mimic4872_complete.csv')

# %% [markdown]
# ## Add 'hospital_expire_flag' column from df_source to df_target

# %%
#12h eICU
df7['hospital_expire_flag'] = df3['hospital_expire_flag'].values
print(df7.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3786 entries, 0 to 3785
# Data columns (total 69 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Cefalosporine         3786 non-null   float64
#  1   Macrolide             3786 non-null   float64
#  2   Meropenem             3786 non-null   float64
#  3   Metronidazole         3786 non-null   float64
#  4   Penicillin            3786 non-null   float64
#  5   Quinolone             3786 non-null   float64
#  6   Vancomycin            3786 non-null   float64
#  7   gcs_min               3786 non-null   float64
#  8   gcs_motor             3786 non-null   float64
#  9   gcs_verbal            3786 non-null   float64
#  10  gcs_eyes              3786 non-null   float64
#  11  age                   3786 non-null   int64
#  12  sex                   3786 non-null   int64
#  13  race                  3786 non-null   int64
# ...

# %%
#24h eICU
df8['hospital_expire_flag'] = df1['hospital_expire_flag'].values
print(df8.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3786 entries, 0 to 3785
# Data columns (total 69 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Cefalosporine         3786 non-null   float64
#  1   Macrolide             3786 non-null   float64
#  2   Meropenem             3786 non-null   float64
#  3   Metronidazole         3786 non-null   float64
#  4   Penicillin            3786 non-null   float64
#  5   Quinolone             3786 non-null   float64
#  6   Vancomycin            3786 non-null   float64
#  7   gcs_min               3786 non-null   float64
#  8   gcs_motor             3786 non-null   float64
#  9   gcs_verbal            3786 non-null   float64
#  10  gcs_eyes              3786 non-null   float64
#  11  age                   3786 non-null   int64
#  12  sex                   3786 non-null   int64
#  13  race                  3786 non-null   int64
# ...

# %%
#48h eICU
df9['hospital_expire_flag'] = df5['hospital_expire_flag'].values
print(df9.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3786 entries, 0 to 3785
# Data columns (total 69 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Cefalosporine         3786 non-null   float64
#  1   Macrolide             3786 non-null   float64
#  2   Meropenem             3786 non-null   float64
#  3   Metronidazole         3786 non-null   float64
#  4   Penicillin            3786 non-null   float64
#  5   Quinolone             3786 non-null   float64
#  6   Vancomycin            3786 non-null   float64
#  7   gcs_min               3786 non-null   float64
#  8   gcs_motor             3786 non-null   float64
#  9   gcs_verbal            3786 non-null   float64
#  10  gcs_eyes              3786 non-null   float64
#  11  age                   3786 non-null   int64
#  12  sex                   3786 non-null   int64
#  13  race                  3786 non-null   int64
# ...

# %%
#12h MIMIC
df10['hospital_expire_flag'] = df4['hospital_expire_flag'].values
print(df10.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7511 entries, 0 to 7510
# Data columns (total 69 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Cefalosporine         7511 non-null   float64
#  1   Macrolide             7511 non-null   float64
#  2   Meropenem             7511 non-null   float64
#  3   Metronidazole         7511 non-null   float64
#  4   Penicillin            7511 non-null   float64
#  5   Quinolone             7511 non-null   float64
#  6   Vancomycin            7511 non-null   float64
#  7   gcs_min               7511 non-null   float64
#  8   gcs_motor             7511 non-null   float64
#  9   gcs_verbal            7511 non-null   float64
#  10  gcs_eyes              7511 non-null   float64
#  11  age                   7511 non-null   int64
#  12  sex                   7511 non-null   int64
#  13  race                  7511 non-null   int64
# ...

# %%
#24h MIMIC
df11['hospital_expire_flag'] = df2['hospital_expire_flag'].values
print(df11.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7511 entries, 0 to 7510
# Data columns (total 69 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Cefalosporine         7511 non-null   float64
#  1   Macrolide             7511 non-null   float64
#  2   Meropenem             7511 non-null   float64
#  3   Metronidazole         7511 non-null   float64
#  4   Penicillin            7511 non-null   float64
#  5   Quinolone             7511 non-null   float64
#  6   Vancomycin            7511 non-null   float64
#  7   gcs_min               7511 non-null   float64
#  8   gcs_motor             7511 non-null   float64
#  9   gcs_verbal            7511 non-null   float64
#  10  gcs_eyes              7511 non-null   float64
#  11  age                   7511 non-null   int64
#  12  sex                   7511 non-null   int64
#  13  race                  7511 non-null   int64
# ...

# %%
#48h MIMIC
df12['hospital_expire_flag'] = df6['hospital_expire_flag'].values
print(df12.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7511 entries, 0 to 7510
# Data columns (total 69 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Cefalosporine         7511 non-null   float64
#  1   Macrolide             7511 non-null   float64
#  2   Meropenem             7511 non-null   float64
#  3   Metronidazole         7511 non-null   float64
#  4   Penicillin            7511 non-null   float64
#  5   Quinolone             7511 non-null   float64
#  6   Vancomycin            7511 non-null   float64
#  7   gcs_min               7511 non-null   float64
#  8   gcs_motor             7511 non-null   float64
#  9   gcs_verbal            7511 non-null   float64
#  10  gcs_eyes              7511 non-null   float64
#  11  age                   7511 non-null   int64
#  12  sex                   7511 non-null   int64
#  13  race                  7511 non-null   int64
# ...

# %%
df7.to_csv('ya_imputados/eicu1236f_complete.csv', index = False)
df8.to_csv('ya_imputados/eicu2448f_complete.csv', index = False)
df9.to_csv('ya_imputados/eicu4872f_complete.csv', index = False)
df10.to_csv('ya_imputados/mimic1236f_complete.csv', index = False)
df11.to_csv('ya_imputados/mimic2448f_complete.csv', index = False)
df12.to_csv('ya_imputados/mimic4872f_complete.csv', index = False)
